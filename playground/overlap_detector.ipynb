# %%
import numpy as np

from shared.mat_reader import MatReader

mat_reader = MatReader("/Users/james/GitHub/lampe/lampe_dataset/Full images")

last_idx = np.where(mat_reader.class_labels == 0)[0][-1]

a = mat_reader.patient_ids[:last_idx + 1]
b = mat_reader.patient_ids[last_idx + 1:]

com = np.intersect1d(a, b)
print(com)

print(np.where(np.isin(mat_reader.patient_ids, com)))
# Out:
# ['1_B3' '1_E5']
# (array([ 19,  20,  38, 103, 112, 113, 114]),)
